# %%
import pandas as pd

# %%
df = pd.read_csv("asd.csv")
df.head(-1)
# Out:
#             date Price_x Open_x High_x Low_x Vol._x Change %_x  \
# 0            NaN     NaN    NaN    NaN   NaN    NaN        NaN
# 1     2015-01-05     NaN    NaN    NaN   NaN    NaN        NaN
# 2     2015-01-12     NaN    NaN    NaN   NaN    NaN        NaN
# 3     2015-01-19     NaN    NaN    NaN   NaN    NaN        NaN
# 4     2015-01-26     NaN    NaN    NaN   NaN    NaN        NaN
# ...          ...     ...    ...    ...   ...    ...        ...
# 1880  2023-06-09     NaN    NaN    NaN   NaN    NaN        NaN
# 1881  2023-06-10     NaN    NaN    NaN   NaN    NaN        NaN
# 1882  2023-06-13     NaN    NaN    NaN   NaN    NaN        NaN
# 1883  2023-06-14     NaN    NaN    NaN   NaN    NaN        NaN
# 1884  2023-06-15     NaN    NaN    NaN   NaN    NaN        NaN
#
#       Цена на арматуру_x  Индекс стоимости грузоперевозок  Импорт цемента ЖД  \
# 0                    NaN                              NaN                NaN
# ...

# %%
df = df.dropna(subset=["Цена на арматуру_x"])
df.head(-1)
# Out:
#             date Price_x  Open_x  High_x   Low_x   Vol._x Change %_x  \
# 1     2015-01-05     NaN     NaN     NaN     NaN      NaN        NaN
# 2     2015-01-12     NaN     NaN     NaN     NaN      NaN        NaN
# 3     2015-01-19     NaN     NaN     NaN     NaN      NaN        NaN
# 4     2015-01-26     NaN     NaN     NaN     NaN      NaN        NaN
# 5     2015-02-02     NaN     NaN     NaN     NaN      NaN        NaN
# ...          ...     ...     ...     ...     ...      ...        ...
# 1609  2022-07-25  695.00  688.80  698.60  679.80  801.23K      0.78%
# 1616  2022-08-01  732.00  736.60  754.60  732.00    1.07M     -0.25%
# 1622  2022-08-08  683.60  714.00  714.00  683.60  529.46K      0.53%
# 1628  2022-08-15  708.20  708.40  708.40  695.20  422.71K      1.17%
# 1634  2022-08-22  708.00  704.60  709.40  699.80  255.55K      0.65%
#
#       Цена на арматуру_x  Индекс стоимости грузоперевозок  Импорт цемента ЖД  \
# ...

# %%
df = df.loc[:, ~df.T.duplicated()]
df = df.dropna(axis=1, how='all')


df.head(-1)
# Out:
#             date Price_x  Open_x  High_x   Low_x   Vol._x Change %_x  \
# 1     2015-01-05     NaN     NaN     NaN     NaN      NaN        NaN
# 2     2015-01-12     NaN     NaN     NaN     NaN      NaN        NaN
# 3     2015-01-19     NaN     NaN     NaN     NaN      NaN        NaN
# 4     2015-01-26     NaN     NaN     NaN     NaN      NaN        NaN
# 5     2015-02-02     NaN     NaN     NaN     NaN      NaN        NaN
# ...          ...     ...     ...     ...     ...      ...        ...
# 1609  2022-07-25  695.00  688.80  698.60  679.80  801.23K      0.78%
# 1616  2022-08-01  732.00  736.60  754.60  732.00    1.07M     -0.25%
# 1622  2022-08-08  683.60  714.00  714.00  683.60  529.46K      0.53%
# 1628  2022-08-15  708.20  708.40  708.40  695.20  422.71K      1.17%
# 1634  2022-08-22  708.00  704.60  709.40  699.80  255.55K      0.65%
#
#       Цена на арматуру_x  Импорт цемента ЖД  Экспорт цемента ЖД  ...  Макс.  \
# ...

# %%
missing_values = df.isna().sum()

missing_percentage = (missing_values / len(df)) * 100

df = df.loc[:, missing_percentage <= 95]
df.head(-1)
# Out:
#             date Price_x  Open_x  High_x   Low_x   Vol._x Change %_x  \
# 1     2015-01-05     NaN     NaN     NaN     NaN      NaN        NaN
# 2     2015-01-12     NaN     NaN     NaN     NaN      NaN        NaN
# 3     2015-01-19     NaN     NaN     NaN     NaN      NaN        NaN
# 4     2015-01-26     NaN     NaN     NaN     NaN      NaN        NaN
# 5     2015-02-02     NaN     NaN     NaN     NaN      NaN        NaN
# ...          ...     ...     ...     ...     ...      ...        ...
# 1609  2022-07-25  695.00  688.80  698.60  679.80  801.23K      0.78%
# 1616  2022-08-01  732.00  736.60  754.60  732.00    1.07M     -0.25%
# 1622  2022-08-08  683.60  714.00  714.00  683.60  529.46K      0.53%
# 1628  2022-08-15  708.20  708.40  708.40  695.20  422.71K      1.17%
# 1634  2022-08-22  708.00  704.60  709.40  699.80  255.55K      0.65%
#
#       Цена на арматуру_x   цена  Ключевая ставка  ...  Макс.   Мин.   Объём  \
# ...

# %%
missing_values = df.isna().sum()
print(missing_values)
# Out:
# date          0
# Price_x     222
# Open_x      222
# High_x      222
# Low_x       222
#            ...
# Open        223
# High        223
# Low         223
# Vol.        223
# Change %    223
# Length: 69, dtype: int64

# %%
# Заполняем пустые значения 0
df = df.fillna(0)

# Проверяем, остались ли пропуски
print(df.isnull().sum())
# # Удаляем строки с NaN
# merged_df = merged_df.dropna()

# # Проверяем, остались ли пропуски
# print(merged_df.isnull().sum())
# Out:
# date        0
# Price_x     0
# Open_x      0
# High_x      0
# Low_x       0
#            ..
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# Length: 69, dtype: int64

# %% [markdown]
# ## Пробуем чекнуть что будет

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("asd.csv")

# %%
df.rename(columns=lambda x: x.strip().lower(), inplace=True)
print("Столбцы в датасете:", df.columns)
print(df.head())
print(df.dtypes)
df.head(-1)
# Out:
# Столбцы в датасете: Index(['date', 'price_x', 'open_x', 'high_x', 'low_x', 'vol._x', 'change %_x',
#        'цена на арматуру_x', 'индекс стоимости грузоперевозок',
#        'импорт цемента жд',
#        ...
#        'low_y', 'vol._y', 'change %_y', 'цена на арматуру_y', 'price', 'open',
#        'high', 'low', 'vol.', 'change %'],
#       dtype='object', length=186)
#          date price_x open_x high_x low_x vol._x change %_x  \
# 0         NaN     NaN    NaN    NaN   NaN    NaN        NaN
# 1  2015-01-05     NaN    NaN    NaN   NaN    NaN        NaN
# 2  2015-01-12     NaN    NaN    NaN   NaN    NaN        NaN
# 3  2015-01-19     NaN    NaN    NaN   NaN    NaN        NaN
# 4  2015-01-26     NaN    NaN    NaN   NaN    NaN        NaN
#
#    цена на арматуру_x  индекс стоимости грузоперевозок  импорт цемента жд  \
# 0                 NaN                              NaN                NaN
# 1             32900.0                              NaN                NaN
# ...

# %%
date_column = next((col for col in df.columns if "date" in col.lower()), None)
if date_column is None:
    raise KeyError("Не найден столбец с датой в датасете. Проверьте названия столбцов.")

df[date_column] = pd.to_datetime(df[date_column], errors="coerce")
df.dropna(subset=[date_column], inplace=True)
df.sort_values(by=date_column, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
if len(numeric_columns) < 1:
    raise ValueError("В датасете нет числовых столбцов для анализа.")
target_column = numeric_columns[0]

# Удаление выбросов
q1 = df[target_column].quantile(0.25)
q3 = df[target_column].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(df[target_column] >= lower_bound) & (df[target_column] <= upper_bound)]

# Заполнение пропущенных значений
if df[target_column].isna().sum() > 0:
    df[target_column].fillna(df[target_column].median(), inplace=True)

# Визуализируем динамику цены
plt.figure(figsize=(12, 6))
plt.plot(df[date_column], df[target_column], marker="o", linestyle="-", color="b", alpha=0.7)
plt.xlabel("Дата")
plt.ylabel("Цена арматуры")
plt.title("Динамика цены на арматуру")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
df.head(-1)
# Out:
#            date price_x  open_x  high_x   low_x   vol._x change %_x  \
# 1    2015-01-05     NaN     NaN     NaN     NaN      NaN        NaN
# 2    2015-01-12     NaN     NaN     NaN     NaN      NaN        NaN
# 3    2015-01-19     NaN     NaN     NaN     NaN      NaN        NaN
# 4    2015-01-26     NaN     NaN     NaN     NaN      NaN        NaN
# 5    2015-02-02     NaN     NaN     NaN     NaN      NaN        NaN
# ...         ...     ...     ...     ...     ...      ...        ...
# 1609 2022-07-25  695.00  688.80  698.60  679.80  801.23K      0.78%
# 1616 2022-08-01  732.00  736.60  754.60  732.00    1.07M     -0.25%
# 1622 2022-08-08  683.60  714.00  714.00  683.60  529.46K      0.53%
# 1628 2022-08-15  708.20  708.40  708.40  695.20  422.71K      1.17%
# 1634 2022-08-22  708.00  704.60  709.40  699.80  255.55K      0.65%
#
#       цена на арматуру_x  индекс стоимости грузоперевозок  импорт цемента жд  \
# ...

# %%
df["time_index"] = range(len(df))

# Добавляем новые признаки
df["rolling_mean"] = df[target_column].rolling(window=5, min_periods=1).mean()
df["lag_1"] = df[target_column].shift(1)
df["lag_2"] = df[target_column].shift(2)
df.fillna(method="bfill", inplace=True)
df.head

if df.shape[0] == 0:
    raise ValueError("После предобработки нет данных. Проверьте фильтрацию и генерацию признаков.")

# Разделяем данные на признаки и целевую переменную
feature_columns = ["time_index", "rolling_mean", "lag_1", "lag_2"]
X = df[feature_columns].values
y = df[target_column].values

# Проверка размера данных перед разделением
if X.shape[0] == 0 or y.shape[0] == 0:
    raise ValueError("Данные пустые перед train_test_split. Проверьте предобработку.")

# Разделяем на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Проверка размера выборок
if X_train.shape[0] == 0 or X_test.shape[0] == 0:
    raise ValueError("Ошибка в train_test_split: одна из выборок пустая.")

# Масштабирование данных
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Список моделей
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(n_estimators=500, max_depth=15, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=500, learning_rate=0.01, max_depth=7, random_state=42),
    "Support Vector Regression": SVR(kernel="rbf", C=500, gamma=0.05),
    "XGBoost": XGBRegressor(objective="reg:squarederror", n_estimators=500, learning_rate=0.01, max_depth=7, random_state=42)
}

# Обучаем и оцениваем модели
results = {}
plt.figure(figsize=(12, 6))
# Out:
# C:\Users\josha\AppData\Local\Temp\ipykernel_30480\2255140316.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill", inplace=True)

# %%
# for name, model in models.items():
#     model.fit(X_train, y_train)
#     y_pred = model.predict(X_test)
#     mae = mean_absolute_error(y_test, y_pred)
#     rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#     r2 = r2_score(y_test, y_pred)
#     results[name] = {"MAE": mae, "RMSE": rmse, "R2": r2}
#     plt.plot(df[date_column].iloc[-len(y_test):], y_pred, label=name)

# %%
# results_df = pd.DataFrame(results).T
# print(results_df)

# # График прогнозов
# plt.plot(df[date_column].iloc[-len(y_test):], y_test, label="Истинные значения", color="black", linestyle="dashed")
# plt.xlabel("Дата")
# plt.ylabel("Цена арматуры")
# plt.title("Прогнозы моделей на тестовых данных")
# plt.legend()
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.show()

# %%
# future_steps = 30
# future_indexes = np.arange(len(df), len(df) + future_steps)
# future_X = np.array([future_indexes, np.full(future_steps, np.mean(y)), np.roll(y, 1)[-future_steps:], np.roll(y, 2)[-future_steps:]]).T
# future_X = scaler.transform(future_X)

# plt.figure(figsize=(12, 6))
# plt.plot(df[date_column], df[target_column], label="Исходные данные", color="black")
# for name, model in models.items():
#     future_preds = model.predict(future_X)
#     future_dates = pd.date_range(start=df[date_column].iloc[-1], periods=future_steps + 1, freq='D')[1:]
#     plt.plot(future_dates, future_preds, label=f"Прогноз {name}")

# plt.xlabel("Дата")
# plt.ylabel("Цена арматуры")
# plt.title("Прогнозирование будущих значений")
# plt.legend()
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.show()

# %%
# results = {}
# for name, model in models.items():
#     model.fit(X_train, y_train)
#     y_pred = model.predict(X_test)
#     mae = mean_absolute_error(y_test, y_pred)
#     rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#     r2 = r2_score(y_test, y_pred)
#     results[name] = {"MAE": mae, "RMSE": rmse, "R2": r2}
    
#     plt.figure(figsize=(12, 6))
#     plt.plot(df[date_column].iloc[-len(y_test):], y_pred, label=name, color="blue")
#     plt.plot(df[date_column].iloc[-len(y_test):], y_test, label="Исходные данные", color="black")
#     plt.xlabel("Дата")
#     plt.ylabel("Цена арматуры")
#     plt.title(f"Прогноз {name}")
#     plt.legend()
#     plt.grid(True)
#     plt.xticks(rotation=45)
#     plt.show()

# # Выводим результаты
# results_df = pd.DataFrame(results).T
# print(results_df)

# %%
# future_X = np.array([[X_test[-1, 0] + i] + list(X_test[-1, 1:]) for i in range(1, future_steps + 1)])
# future_X = scaler.transform(future_X)
# future_preds = model.predict(future_X)
    
#     # График предсказаний
# plt.figure(figsize=(12, 6))
# plt.plot(df[date_column].iloc[-len(y_test):], y_pred, label=name, color="blue")
# plt.plot(df[date_column].iloc[-len(y_test):], y_test, label="Исходные данные", color="black")
# plt.plot(future_dates, future_preds, label="Прогноз на будущее", linestyle="dashed", color="red")
# plt.xlabel("Дата")
# plt.ylabel("Цена арматуры")
# plt.title(f"Прогноз {name}")
# plt.legend()
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.show()

# # Выводим результаты
# results_df = pd.DataFrame(results).T
# print(results_df)

# %%
# # Обучаем и оцениваем модели
# results = {}
# future_steps = 10
# future_dates = pd.date_range(start=df[date_column].iloc[-1], periods=future_steps + 1, freq="D")[1:]
# for name, model in models.items():
#     model.fit(X_train, y_train)
#     y_pred = model.predict(X_test)
#     mae = mean_absolute_error(y_test, y_pred)
#     rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#     r2 = r2_score(y_test, y_pred)
#     results[name] = {"MAE": mae, "RMSE": rmse, "R2": r2}
    
#     # Прогноз на будущее
#     future_X = np.array([[X_test[-1, 0] + i] + list(X_test[-1, 1:]) for i in range(1, future_steps + 1)])
#     future_X = scaler.transform(future_X)
#     future_preds = model.predict(future_X)
    
#     # График предсказаний
#     plt.figure(figsize=(12, 6))
#     plt.plot(df[date_column].iloc[-len(y_test):], y_pred, label=name, color="blue")
#     plt.plot(df[date_column].iloc[-len(y_test):], y_test, label="Исходные данные", color="black")
#     plt.plot(future_dates, future_preds, label="Прогноз на будущее", linestyle="dashed", color="red")
#     plt.xlabel("Дата")
#     plt.ylabel("Цена арматуры")
#     plt.title(f"Прогноз {name}")
#     plt.legend()
#     plt.grid(True)
#     plt.xticks(rotation=45)
#     plt.show()

# # Выводим результаты
# results_df = pd.DataFrame(results).T
# print(results_df)

# %%
# Out:
# Столбцы в датасете: Index(['date', 'price_x', 'open_x', 'high_x', 'low_x', 'vol._x', 'change %_x',
#        'цена на арматуру_x', 'индекс стоимости грузоперевозок',
#        'импорт цемента жд',
#        ...
#        'low_y', 'vol._y', 'change %_y', 'цена на арматуру_y', 'price', 'open',
#        'high', 'low', 'vol.', 'change %'],
#       dtype='object', length=186)
#          date price_x open_x high_x low_x vol._x change %_x  \
# 0         NaN     NaN    NaN    NaN   NaN    NaN        NaN
# 1  2015-01-05     NaN    NaN    NaN   NaN    NaN        NaN
# 2  2015-01-12     NaN    NaN    NaN   NaN    NaN        NaN
# 3  2015-01-19     NaN    NaN    NaN   NaN    NaN        NaN
# 4  2015-01-26     NaN    NaN    NaN   NaN    NaN        NaN
#
#    цена на арматуру_x  индекс стоимости грузоперевозок  импорт цемента жд  \
# 0                 NaN                              NaN                NaN
# 1             32900.0                              NaN                NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, r2_score


df = pd.read_excel("asd.xlsx", sheet_name="Sheet1")
df["dt"] = pd.to_datetime(df["dt"])
df.set_index("dt", inplace=True)
df.dropna(inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Цена на арматуру"], label="Цена на арматуру", color="b")
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.title("Динамика цены на арматуру")
plt.legend()
plt.grid()
plt.show()

df["month"] = df.index.month  # месяц
df["year"] = df.index.year    # год
df["week"] = df.index.isocalendar().week  # неделя года


model = SARIMAX(df["Цена на арматуру"],
                order=(1, 1, 1),  
                seasonal_order=(1, 1, 1, 52),  
                enforce_stationarity=False, 
                enforce_invertibility=False)


sarimax_model = model.fit(disp=False)


forecast_steps = 30
forecast = sarimax_model.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(df.index[-1], periods=forecast_steps + 1, freq='W')[1:]

forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int()

plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Цена на арматуру"], label="Исторические данные", color="black", linewidth=2)
plt.plot(forecast_index, forecast_mean, label="Прогноз", color="red", linestyle="--", linewidth=2)
plt.fill_between(forecast_index, forecast_ci.iloc[:, 0], forecast_ci.iloc[:, 1], color='red', alpha=0.2)
plt.xlabel("Дата")
plt.ylabel("Цена на арматуру")
plt.title("Прогноз цен на арматуру на 7 недель вперёд с учетом сезонности")
plt.legend()
plt.grid()
plt.show()

y_true = df["Цена на арматуру"].iloc[-forecast_steps:]
mae = mean_absolute_error(y_true, forecast_mean)
r2 = r2_score(y_true, forecast_mean)
print(f"MAE: {mae}")
print(f"R2: {r2}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 from sklearn.metrics import mean_absolute_error, r2_score
#       7 # Загрузка данных
# ----> 8 df = pd.read_excel("asd.xlsx", sheet_name="Sheet1")
#       9 df["dt"] = pd.to_datetime(df["dt"])
#      10 df.set_index("dt", inplace=True)
#
# File c:\Users\josha\OneDrive\Documents\GitHub\3_intensiv_3\.venv\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...
